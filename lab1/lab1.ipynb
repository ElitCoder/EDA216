# %% [markdown]
# # Lab 1 - SQL
#
# *Objective:* you will learn to write SQL queries and practice using
# [`SQLite`]() and [`Jupyter`]()
#
# ## Background
#
# A database for registration of courses, students, and course results
# has been developed. The purpose was not to develop a new Ladok
# database (Swedish university student database), so everything has been
# simplified as much as possible. A course has a course code (e.g.,
# EDA216), a name (e.g., Database Technology), a level (G1, G2 or A) and
# a number of credits (e.g., 7.5). Students have a social security
# number (personnummer) and a name. When a student has passed a course
# his/her grade (3, 4 or 5) is registered in the database.
#
# We started by developing an E/R model of the system (E/R stands for
# Entity-Relationship). This model is developed in the same way as when
# you develop the static model in object-oriented modeling, and you draw
# the same kind of UML diagrams. You may instead use traditional E/R
# notation, as in the text book. However, diagrams in the traditional
# notation take more paper space, and the notation is not fully
# standardized, so we will only use the UML notation. The model looks
# like this in the different notations (the UML diagram is at the top):
#
# ![There should be a image here](lab1.png)
#
# The E/R model is then converted into a database schema in the
# relational model. We will later show how the conversion is performed;
# for now we just show the final results. The entity sets and the
# relationship have been converted into the following relations (the
# primary key of each relation is italicized):
#
#  + Students(*ssn*, first_name, last_name)
#  + Courses(*course_code*, course_name, level, credits)
#  + TakenCourses(*ssn, course_code*, grade)
#
# Examples of instances of the relations:

# %% [markdown]
# ~~~ {.text}
# ssn           first_name   last_name
# 861103–2438   Bo           Ek
# 911212–1746   Eva          Alm
# 950829–1848   Anna         Nyström
# ...           ...          ...
#
# course_code   course_name                   level    credits
# EDA016        Programmeringsteknik          G1       7.5
# EDAA01        Programmeringsteknik - FK     G1       7.5
# EDA230        Optimerande kompilatorer      A        7.5
# ...           ...                           ...      ...
#
# ssn           course_code   grade
# 861103–2438   EDA016        4
# 861103–2438   EDAA01        3
# 911212–1746   EDA016        3
# ...           ...           ...
# ~~~

# %% [markdown]
# The tables have been created with the following SQL statements:

# %% [markdown]
# ~~~ {.sql}
# CREATE TABLE students (
#     ssn          char(11),
#     first_name   varchar(20) not null,
#     last_name    varchar(20) not null,
#     primary key  (ssn)
# );
#
# CREATE TABLE courses (
#     course_code   char(6),
#     course_name   varchar(70) not null,
#     level         char(2),
#     credits       double not null check (credits > 0),
#     primary key   (course_code)
# );
#
# CREATE TABLE taken_courses (
#     ssn           char(11),
#     course_code   char(6),
#     grade         integer not null check (grade >= 3 and grade <= 5),
#     primary key   (ssn, course_code),
#     foreign key   (ssn) references students(ssn),
#     foreign key   (course_code) references courses(course_code)
# );
# ~~~

# %% [markdown]
# All courses that were offered at the Computer Science and Engineering
# program at LTH during the academic year 2013/14 are in the table
# Courses. Also, the database has been filled with invented data about
# students and what courses they have taken. SQL statements like the
# following have been used to insert the data:

# %% [markdown]
# ~~~ {.sql}
# INSERT INTO students      VALUES (’861103-2438’, ’Bo’, ’Ek’);
# INSERT INTO courses       VALUES (’EDA016’, ’Programmeringsteknik’, ’G1’, 7.5);
# INSERT INTO taken_courses VALUES (’861103-2438’, ’EDA016’, 4);
# ~~~

# %% [markdown]
# ## Assignments

# %%
# %load_ext sql

# %%
# %sql sqlite:///lab1.db
# Out:
# u'Connected: None@lab1.db'

# %% [markdown]
# The tables `students`, `courses` and `taken_courses` already exist in
# your database. If you change the contents of the tables, you can
# always recreate the tables with the following command (at the mysql
# prompt):

# %% [markdown]
# ~~~ {.sh}
# sqlite3 lab1.db < setup-lab1-db.sql
# ~~~

# %% [markdown]
# After most of the questions there is a number in brackets. This is the
# number of rows generated by the question. For instance, [72] after
# question a) means that there are 72 students in the database.
#
# a) What are the names (first name, last name) of all the students?
#    [72]

# %%
# %%sql
# SELECT DISTINCT first_name, last_name
# FROM students;
# Out:
# Done.
# [(u'Anna', u'Johansson'),
#  (u'Eva', u'Alm'),
#  (u'Eva', u'Nilsson'),
#  (u'Elaine', u'Robertson'),
#  (u'Maria', u'Nordman'),
#  (u'Helena', u'Troberg'),
#  (u'Lotta', u'Emanuelsson'),
#  (u'Anna', u'Nystr\xf6m'),
#  (u'Maria', u'Andersson'),
#  (u'Marie', u'Persson'),
#  (u'M\xe4rit', u'Aspegren'),
#  (u'Ylva', u'Jacobsson'),
#  (u'Frida', u'Weidel'),
#  (u'Caroline', u'Olsson'),
#  (u'Karolin', u'Ek'),
#  (u'Eva', u'Hjort'),
#  (u'Sofia', u'Kjellberg'),
#  (u'Tina', u'L\xf6\xf6f'),
#  (u'Lisa', u'Berg'),
#  (u'Lotta', u'Bergman'),
#  (u'Susanne', u'Dahl'),
#  (u'Birgit', u'Ewesson'),
#  (u'Ulrika', u'Jonsson'),
#  (u'Jenny', u'Lundin'),
#  (u'Karin', u'\xd6stberg'),
#  (u'Bo', u'Ek'),
#  (u'Erik', u'Andersson'),
#  (u'Filip', u'Gustavsson'),
#  (u'Niklas', u'Andersson'),
#  (u'David', u'Carlsson'),
#  (u'Tobias', u'Enberg'),
#  (u'Johan', u'Lind'),
#  (u'Magnus', u'Pettersson'),
#  (u'Filip', u'Persson'),
#  (u'Ola', u'Nilsson'),
#  (u'Jakob', u'Malmberg'),
#  (u'Henrik', u'Berg'),
#  (u'John', u'Lind'),
#  (u'Patrik', u'Lundh'),
#  (u'Mikael', u'Nilsson'),
#  (u'Joakim', u'Nilsson'),
#  (u'Conny', u'Modig'),
#  (u'Christian', u'Wallman'),
#  (u'Magnus', u'Str\xf6mgren'),
#  (u'Daniel', u'Ahlman'),
#  (u'Lars', u'Molin'),
#  (u'Magnus', u'Nilsson'),
#  (u'Anders', u'Olsson'),
#  (u'Martin', u'Alm'),
#  (u'H\xe5kan', u'Mossgren'),
#  (u'Fredrik', u'Ryd'),
#  (u'Mats', u'Wikstr\xf6m'),
#  (u'Anders', u'Magnusson'),
#  (u'Andreas', u'Molin'),
#  (u'Johan', u'Brattberg'),
#  (u'Johan', u'Olsson'),
#  (u'Jonathan', u'J\xf6nsson'),
#  (u'Magnus', u'Hultgren'),
#  (u'Axel', u'Nord'),
#  (u'Henrik', u'Hult'),
#  (u'Joakim', u'Hall'),
#  (u'Henrik', u'Gustavsson'),
#  (u'Torbj\xf6rn', u'Modig'),
#  (u'Daniel', u'Axelsson'),
#  (u'Per-Erik', u'Pettersson'),
#  (u'Roger', u'Brorsson'),
#  (u'Patrik', u'Ohlsson'),
#  (u'Peter', u'Solberg')]

# %% [markdown]
# b) Same as question a) but produce a sorted listing. Sort first by
#    last name and then by first name.

# %%
# %%sql
# SELECT first_name, last_name
# FROM students
# ORDER BY first_name, last_name;
# Out:
# Done.
# [(u'Anders', u'Magnusson'),
#  (u'Anders', u'Olsson'),
#  (u'Andreas', u'Molin'),
#  (u'Anna', u'Johansson'),
#  (u'Anna', u'Johansson'),
#  (u'Anna', u'Nystr\xf6m'),
#  (u'Axel', u'Nord'),
#  (u'Birgit', u'Ewesson'),
#  (u'Bo', u'Ek'),
#  (u'Bo', u'Ek'),
#  (u'Bo', u'Ek'),
#  (u'Caroline', u'Olsson'),
#  (u'Christian', u'Wallman'),
#  (u'Conny', u'Modig'),
#  (u'Daniel', u'Ahlman'),
#  (u'Daniel', u'Axelsson'),
#  (u'David', u'Carlsson'),
#  (u'Elaine', u'Robertson'),
#  (u'Erik', u'Andersson'),
#  (u'Erik', u'Andersson'),
#  (u'Eva', u'Alm'),
#  (u'Eva', u'Hjort'),
#  (u'Eva', u'Nilsson'),
#  (u'Filip', u'Gustavsson'),
#  (u'Filip', u'Persson'),
#  (u'Fredrik', u'Ryd'),
#  (u'Frida', u'Weidel'),
#  (u'Helena', u'Troberg'),
#  (u'Henrik', u'Berg'),
#  (u'Henrik', u'Gustavsson'),
#  (u'Henrik', u'Hult'),
#  (u'H\xe5kan', u'Mossgren'),
#  (u'Jakob', u'Malmberg'),
#  (u'Jenny', u'Lundin'),
#  (u'Joakim', u'Hall'),
#  (u'Joakim', u'Nilsson'),
#  (u'Johan', u'Brattberg'),
#  (u'Johan', u'Lind'),
#  (u'Johan', u'Olsson'),
#  (u'John', u'Lind'),
#  (u'Jonathan', u'J\xf6nsson'),
#  (u'Karin', u'\xd6stberg'),
#  (u'Karolin', u'Ek'),
#  (u'Lars', u'Molin'),
#  (u'Lisa', u'Berg'),
#  (u'Lotta', u'Bergman'),
#  (u'Lotta', u'Emanuelsson'),
#  (u'Magnus', u'Hultgren'),
#  (u'Magnus', u'Nilsson'),
#  (u'Magnus', u'Pettersson'),
#  (u'Magnus', u'Str\xf6mgren'),
#  (u'Maria', u'Andersson'),
#  (u'Maria', u'Nordman'),
#  (u'Marie', u'Persson'),
#  (u'Martin', u'Alm'),
#  (u'Mats', u'Wikstr\xf6m'),
#  (u'Mikael', u'Nilsson'),
#  (u'M\xe4rit', u'Aspegren'),
#  (u'Niklas', u'Andersson'),
#  (u'Ola', u'Nilsson'),
#  (u'Patrik', u'Lundh'),
#  (u'Patrik', u'Ohlsson'),
#  (u'Per-Erik', u'Pettersson'),
#  (u'Peter', u'Solberg'),
#  (u'Roger', u'Brorsson'),
#  (u'Sofia', u'Kjellberg'),
#  (u'Susanne', u'Dahl'),
#  (u'Tina', u'L\xf6\xf6f'),
#  (u'Tobias', u'Enberg'),
#  (u'Torbj\xf6rn', u'Modig'),
#  (u'Ulrika', u'Jonsson'),
#  (u'Ylva', u'Jacobsson')]

# %% [markdown]
# c) Which students were born in 1985? [4]

# %%
# %%sql
# SELECT first_name, last_name
# FROM students
# WHERE ssn LIKE '85%';
# Out:
# Done.
# [(u'Ulrika', u'Jonsson'),
#  (u'Bo', u'Ek'),
#  (u'Filip', u'Persson'),
#  (u'Henrik', u'Berg')]

# %% [markdown]
# d) What are the names of the female students, and which are their
#    social security numbers? The next-to-last digit in the social
#    security number is even for females. The SQLite function
#    `substr(str,m,n)` returns `n` characters from the string `str`,
#    starting at character `m`. [26]

# %%
# %%sql
# SELECT first_name, last_name
# FROM students
# WHERE substr(ssn, 10, 1) % 2 = 0;
# Out:
# Done.
# [(u'Anna', u'Johansson'),
#  (u'Anna', u'Johansson'),
#  (u'Eva', u'Alm'),
#  (u'Eva', u'Nilsson'),
#  (u'Elaine', u'Robertson'),
#  (u'Maria', u'Nordman'),
#  (u'Helena', u'Troberg'),
#  (u'Lotta', u'Emanuelsson'),
#  (u'Anna', u'Nystr\xf6m'),
#  (u'Maria', u'Andersson'),
#  (u'Marie', u'Persson'),
#  (u'M\xe4rit', u'Aspegren'),
#  (u'Ylva', u'Jacobsson'),
#  (u'Frida', u'Weidel'),
#  (u'Caroline', u'Olsson'),
#  (u'Karolin', u'Ek'),
#  (u'Eva', u'Hjort'),
#  (u'Sofia', u'Kjellberg'),
#  (u'Tina', u'L\xf6\xf6f'),
#  (u'Lisa', u'Berg'),
#  (u'Lotta', u'Bergman'),
#  (u'Susanne', u'Dahl'),
#  (u'Birgit', u'Ewesson'),
#  (u'Ulrika', u'Jonsson'),
#  (u'Jenny', u'Lundin'),
#  (u'Karin', u'\xd6stberg')]

# %% [markdown]
# e) How many students are registered in the database?

# %%
# %%sql
# SELECT COUNT(ssn)
# FROM students
# Out:
# Done.
# [(72,)]

# %% [markdown]
# f) Which courses are offered by the department of Mathematics (course
#    codes `FMAxxx`)? [22]

# %%
# %%sql
# SELECT course_name
# FROM courses
# WHERE course_code LIKE 'FMA%';
# Out:
# Done.
# [(u'Kontinuerliga system',),
#  (u'Optimering',),
#  (u'Diskret matematik',),
#  (u'Matematiska strukturer',),
#  (u'Matristeori',),
#  (u'Matristeori, projektdel',),
#  (u'Geometri',),
#  (u'Olinj\xe4ra dynamiska system',),
#  (u'Olinj\xe4ra dynamiska system, projektdel',),
#  (u'Bildanalys',),
#  (u'Bildanalys, projektdel',),
#  (u'Variationskalkyl',),
#  (u'Linj\xe4r och kombinatorisk optimering',),
#  (u'Datorseende',),
#  (u'Datorseende, projektdel',),
#  (u'Linj\xe4r algebra',),
#  (u'Flerdimensionell analys',),
#  (u'Endimensionell analys',),
#  (u'Matematik - Funktionsteori',),
#  (u'Matematik - System och transformer',),
#  (u'Till\xe4mpad matematik - Linj\xe4ra system',),
#  (u'Algebraiska strukturer',)]

# %% [markdown]
# g) Which courses give more than 7.5 credits? [16]

# %%
# %%sql
# SELECT course_name, credits
# FROM courses
# WHERE credits > 7.5;
# Out:
# Done.
# [(u'Coachning av programvaruteam', 9.0),
#  (u'Datorer i system', 8.0),
#  (u'Till\xe4mpad mekatronik', 10.0),
#  (u'Mekatronik, industriell produktframtagning', 10.0),
#  (u'Digitalteknik', 9.0),
#  (u'Digitala bilder \u2013 kompression', 9.0),
#  (u'Elektromagnetisk f\xe4ltteori', 9.0),
#  (u'Elektronik', 8.0),
#  (u'Introduktionskurs i kinesiska f\xf6r civilingenj\xf6rer', 15.0),
#  (u'Introduktionskurs i kinesiska f\xf6r civilingenj\xf6rer, del 2', 15.0),
#  (u'Fysik', 11.0),
#  (u'Endimensionell analys', 15.0),
#  (u'Matematisk statistik, allm\xe4n kurs', 9.0),
#  (u'Realtidssystem', 10.0),
#  (u'Japanska f\xf6r tekniker', 15.0),
#  (u'Industriell ekonomi, allm\xe4n kurs', 9.0)]

# %% [markdown]
# h) How may courses are there on each level `G1`, `G2` and `A`?

# %%
# %%sql
# SELECT level, COUNT(*)
# FROM courses
# GROUP BY level;
# Out:
# Done.
# [(u'A', 87), (u'G1', 31), (u'G2', 60)]

# %% [markdown]
# i) Which courses (course codes only) have been taken by the student
#    with social security number 910101–1234? [35]

# %%
# %%sql
# SELECT course_code
# FROM taken_courses
# WHERE ssn = '910101-1234';
# Out:
# Done.
# [(u'EDA070',),
#  (u'EDA385',),
#  (u'EDAA25',),
#  (u'EDAF05',),
#  (u'EEMN10',),
#  (u'EIT020',),
#  (u'EIT060',),
#  (u'EITF40',),
#  (u'EITN40',),
#  (u'EITN50',),
#  (u'ESS050',),
#  (u'ETIF10',),
#  (u'ETIF15',),
#  (u'ETIN35',),
#  (u'ETS052',),
#  (u'ETS075',),
#  (u'ETS200',),
#  (u'ETSA01',),
#  (u'EXTA10',),
#  (u'EXTA35',),
#  (u'FAFF20',),
#  (u'FAFF25',),
#  (u'FMA145',),
#  (u'FMA420',),
#  (u'FMAA01',),
#  (u'FMAF05',),
#  (u'FMS012',),
#  (u'FMSF15',),
#  (u'FMSN30',),
#  (u'FMSN35',),
#  (u'FRTN10',),
#  (u'GEMA45',),
#  (u'GEMA70',),
#  (u'MAMF15',),
#  (u'TEK210',)]

# %% [markdown]
# j) What are the names of these courses, and how many credits do they give?

# %%
# %%sql
# SELECT course_name, credits
# FROM courses, taken_courses
# WHERE taken_courses.ssn = '910101-1234'
#     AND taken_courses.course_code = courses.course_code;
# Out:
# Done.
# [(u'Datorer och datoranv\xe4ndning', 3.0),
#  (u'Konstruktion av inbyggda system, f\xf6rdjupningskurs', 7.5),
#  (u'C-programmering', 3.0),
#  (u'Algoritmer, datastrukturer och komplexitet', 5.0),
#  (u'Datorbaserade m\xe4tsystem', 7.5),
#  (u'Digitalteknik', 9.0),
#  (u'Datas\xe4kerhet', 7.5),
#  (u'Digitala och analoga projekt', 7.5),
#  (u'Avancerad webbs\xe4kerhet', 4.0),
#  (u'Avancerad datas\xe4kerhet', 7.5),
#  (u'Elektromagnetisk f\xe4ltteori', 9.0),
#  (u'Signalbehandling - design och implementering', 7.5),
#  (u'Medicinsk signalbehandling', 7.5),
#  (u'IC-projekt 1', 7.5),
#  (u'Datorkommunikation', 4.5),
#  (u'K\xf6system', 4.5),
#  (u'Programvarutestning', 7.5),
#  (u'Ingenj\xf6rsprocessen f\xf6r programvaruutveckling - metodik', 5.0),
#  (u'Introduktion till Kinas samh\xe4llsliv, kultur och spr\xe5k', 3.0),
#  (u'Introduktionskurs i kinesiska f\xf6r civilingenj\xf6rer', 15.0),
#  (u'Multispektral avbildning', 7.5),
#  (u'Fysik', 11.0),
#  (u'Olinj\xe4ra dynamiska system, projektdel', 3.0),
#  (u'Linj\xe4r algebra', 6.0),
#  (u'Endimensionell analys', 15.0),
#  (u'Matematik - System och transformer', 7.0),
#  (u'Matematisk statistik, allm\xe4n kurs', 9.0),
#  (u'Markovprocesser', 7.5),
#  (u'Linj\xe4r och logistisk regression', 7.5),
#  (u'Station\xe4r och icke-station\xe4r spektralanalys', 7.5),
#  (u'Flervariabel reglering', 7.5),
#  (u'F\xf6rst\xe5else och l\xe4rande', 3.0),
#  (u'Japanska f\xf6r tekniker', 15.0),
#  (u'Arbetsorganisation och ledarskap', 6.0),
#  (u'Kognition', 4.5)]

# %% [markdown]
# k) How many credits has the student taken?

# %%
# %%sql
# SELECT SUM(credits)
# FROM taken_courses, courses
# WHERE ssn = '910101-1234'
#     AND taken_courses.course_code = courses.course_code;
# Out:
# Done.
# [(249.5,)]

# %% [markdown]
# l) Which is the student’s grade average (arithmetic mean, not weighted) on the courses?

# %%
# %%sql
# SELECT AVG(grade)
# FROM taken_courses
# WHERE ssn = '910101-1234';
# Out:
# Done.
# [(4.0285714285714285,)]

# %% [markdown]
# m) Same questions as in questions i)–l), but for the student Eva Alm. [26]

# %%
# %%sql
# SELECT SUM(credits)
# FROM taken_courses, students, courses
# WHERE first_name = 'Eva'
#     AND last_name = 'Alm'
#     AND taken_courses.course_code = courses.course_code
#     AND taken_courses.ssn = students.ssn;
# Out:
# Done.
# [(181.0,)]

# %% [markdown]
# n) Which students have taken 0 credits? [11]

# %%
# %%sql
# SELECT first_name, last_name
# FROM students
#     LEFT JOIN taken_courses ON students.ssn = taken_courses.ssn
# WHERE taken_courses.ssn IS NULL
# Out:
# Done.
# [(u'Anna', u'Nystr\xf6m'),
#  (u'Caroline', u'Olsson'),
#  (u'Bo', u'Ek'),
#  (u'Erik', u'Andersson'),
#  (u'Erik', u'Andersson'),
#  (u'Johan', u'Lind'),
#  (u'Filip', u'Persson'),
#  (u'Jonathan', u'J\xf6nsson'),
#  (u'Magnus', u'Hultgren'),
#  (u'Joakim', u'Hall'),
#  (u'Henrik', u'Gustavsson')]

# %% [markdown]
# o) Which students have the highest grade average? Advice: define and
#    use a view that gives the social security number and grade average
#    for each student.

# %%
# %%sql
# SELECT first_name, MAX(avg_grade)
# FROM students,
#     (
#         SELECT taken_courses.ssn, AVG(grade) AS avg_grade
#         FROM taken_courses
#     );
# Out:
# Done.
# [(u'Anna', 4.025373134328358)]

# %% [markdown]
# p) List the social security number and total number of credits for all
#    students. Students with no credits should be included with 0
#    credits, not null. If you do this with an outer join you might want
#    to use the function coalesce(v1, v2, ...); it returns the first
#    value which is not null. [72]

# %%
# %%sql

# %% [markdown]
# q) Is there more than one student with the same name? If so, who are
#    these students and what are their social security numbers? [7]

# %%
# %%sql
